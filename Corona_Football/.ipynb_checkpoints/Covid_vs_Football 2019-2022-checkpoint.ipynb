# %%
import pandas as pd

# %%
Covid_vs_Football = pd.read_csv("coronavirus vs football worldwide 2019-2022.csv")

# %%
Covid_vs_Football
# Out:
#                                                          Category: All categories
# Country               coronavirus: (5/1/19 - 5/1/22)  football: (5/1/19 - 5/1/22)
# Sierra Leone          NaN                                                     NaN
# Liberia               NaN                                                     NaN
# South Sudan           NaN                                                     NaN
# Malawi                NaN                                                     NaN
# ...                                                                           ...
# Tokelau               NaN                                                     NaN
# Tuvalu                NaN                                                     NaN
# U.S. Outlying Islands NaN                                                     NaN
# Vatican City          NaN                                                     NaN
# ...

# %%
Covid_vs_Football.dropna(inplace=True)

# %%
Covid_vs_Football
# Out:
#                                                         Category: All categories
# Country              coronavirus: (5/1/19 - 5/1/22)  football: (5/1/19 - 5/1/22)
# Italy                98%                                                      2%
# Spain                97%                                                      3%
# Kenya                25%                                                     75%
# United Kingdom       48%                                                     52%
# Ireland              54%                                                     46%
# Nepal                76%                                                     24%
# France               88%                                                     12%
# Nigeria              22%                                                     78%
# United Arab Emirates 84%                                                     16%
# Switzerland          92%                                                      8%
# ...
