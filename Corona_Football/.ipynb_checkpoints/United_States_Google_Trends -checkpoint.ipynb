# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
trends_df=pd.read_csv("trends.csv")

# %%
trends_df
# Out:
#       location  year         category  rank                query
# 0       Global  2001  Consumer Brands     1                Nokia
# 1       Global  2001  Consumer Brands     2                 Sony
# 2       Global  2001  Consumer Brands     3                  BMW
# 3       Global  2001  Consumer Brands     4                 Palm
# 4       Global  2001  Consumer Brands     5                Adobe
# ...        ...   ...              ...   ...                  ...
# 26950  Vietnam  2020           Là Gì?     1   Virus Corona là gì
# 26951  Vietnam  2020           Là Gì?     2  Miễn thị thực là gì
# 26952  Vietnam  2020           Là Gì?     3    Đầu cắt moi là gì
# 26953  Vietnam  2020           Là Gì?     4  Bệnh bạch hầu là gì
# 26954  Vietnam  2020           Là Gì?     5       Đông Lào là gì
#
# [26955 rows x 5 columns]

# %%
us_df=trends_df[trends_df["location"]=="United States"]
us_df.head
# Out:
#             location  year         category  rank                 query
# 540    United States  2006  Movie Showtimes     1   Idiocracy Showtimes
# 541    United States  2006  Movie Showtimes     2        Cars Showtimes
# 542    United States  2006  Movie Showtimes     3       Borat Showtimes
# 543    United States  2006  Movie Showtimes     4    Superman Showtimes
# 544    United States  2006  Movie Showtimes     5  Jesus Camp Showtimes
# ...              ...   ...              ...   ...                   ...
# 26860  United States  2020          Recetas     1                  Flan
# 26861  United States  2020          Recetas     2            Aguachiles
# 26862  United States  2020          Recetas     3           Piña Colada
# 26863  United States  2020          Recetas     4       Arroz con Leche
# 26864  United States  2020          Recetas     5        Tinga de Pollo
#
# [2070 rows x 5 columns]

# %%
tr_2020 = trends_df[trends_df['year'] == 2020]

# %%
tr_2020
# Out:
#       location  year  category  rank                query
# 23975   Global  2020  Searches     1          Coronavirus
# 23976   Global  2020  Searches     2     Election results
# 23977   Global  2020  Searches     3          Kobe Bryant
# 23978   Global  2020  Searches     4                 Zoom
# 23979   Global  2020  Searches     5                  IPL
# ...        ...   ...       ...   ...                  ...
# 26950  Vietnam  2020    Là Gì?     1   Virus Corona là gì
# 26951  Vietnam  2020    Là Gì?     2  Miễn thị thực là gì
# 26952  Vietnam  2020    Là Gì?     3    Đầu cắt moi là gì
# 26953  Vietnam  2020    Là Gì?     4  Bệnh bạch hầu là gì
# 26954  Vietnam  2020    Là Gì?     5       Đông Lào là gì
#
# [2980 rows x 5 columns]

# %%
us_df=tr_2020[tr_2020["location"]=="United States"]

# %%
us_df
# Out:
#             location  year  category  rank                 query
# 26700  United States  2020  Searches     1      Election results
# 26701  United States  2020  Searches     2           Coronavirus
# 26702  United States  2020  Searches     3           Kobe Bryant
# 26703  United States  2020  Searches     4    Coronavirus update
# 26704  United States  2020  Searches     5  Coronavirus symptoms
# ...              ...   ...       ...   ...                   ...
# 26860  United States  2020   Recetas     1                  Flan
# 26861  United States  2020   Recetas     2            Aguachiles
# 26862  United States  2020   Recetas     3           Piña Colada
# 26863  United States  2020   Recetas     4       Arroz con Leche
# 26864  United States  2020   Recetas     5        Tinga de Pollo
#
# [165 rows x 5 columns]

# %%
Sh1 = pd.read_csv("Top 100 Most Googled Questions in the US - Sheet1.csv")
Sh1
# Out:
#     Unnamed: 0                            Keyword Average Jul-Sep 2021
# 0            1                      what to watch                 3.8M
# 1            2                    what time is it                 1.2M
# 2            3  what space movie came out in 1992                 1.2M
# 3            4           how many ounces in a cup                 1.0M
# 4            5           how to screenshot on mac                 1.0M
# ..         ...                                ...                  ...
# 95          96  when is senate voting on stimulus               187.3K
# 96          97          how many seconds in a day               182.0K
# 97          98         what time is it in florida               182.0K
# 98          99   why are flags at half mast today               180.0K
# 99         100         when does nfl season start               180.0K
#
# [100 rows x 3 columns]

# %%
a = [1,2,3]
b = [4,5,6]
plt.bar(a,b)
# Out:
# <BarContainer object of 3 artists>
